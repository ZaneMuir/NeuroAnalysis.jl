# %%
include("../src/IO/neurolynxio.jl")
# Out:
# WARNING: replacing module neurolynxio
# neurolynxio

# %%
using neurolynxio

# %%
@time a = neurolynxio.readNCSFile("/Volumes/DataBank/Sesame/data/spiketrain/RAW/ts13_V1_180511_ABABA_COLORBLOCK/CSC2.ncs");
# Out:
#   6.598303 seconds (4.19 M allocations: 1.345 GiB, 33.81% gc time)

# %%
(a.data[2].qwTimeStamp - a.data[1].qwTimeStamp) / 40000
# Out:
# 0.32

# %%
512 / 40000
# Out:
# 0.0128

# %%
a.header |> println
# Out:
# ######## Neuralynx Data File Header
# ## File Name F:\data\xiaozhanzhan\180511_test#1#2\2018-05-11_20-41-45\CSC2.ncs
# ## Time Opened (m/d/y): 5/11/2018  (h:m:s.ms) 20:41:45.166
# ## Time Closed (m/d/y): 5/11/2018  (h:m:s.ms) 21:55:9.813
#
# -FileType CSC
# -FileVersion 3.3.0
# -RecordSize 1044
#
# -CheetahRev 5.6.3
#
# -HardwareSubSystemName AcqSystem1
# -HardwareSubSystemType DigitalLynxSX
# -SamplingFrequency 40000
# -ADMaxValue 32767
# -ADBitVolts 0.000000015259255192745513
#
# -AcqEntName CSC2
# -NumADChannels 1
# -ADChannel 1
# -InputRange 500
# -InputInverted True
#
# -DSPLowCutFilterEnabled True
# -DspLowCutFrequency 1
# -DspLowCutNumTaps 0
# -DspLowCutFilterType DCO
# -DSPHighCutFilterEnabled True
# -DspHighCutFrequency 6000
# -DspHighCutNumTaps 32
# -DspHighCutFilterType FIR
# -DspDelayCompensation Enabled
# -DspFilterDelay_µs 388
